# %%
import pandas as pd
import statsmodels.api as sm

# %%
def run_ols_regression(df, x_col, y_col):
    df = df.dropna(subset=[x_col, y_col])
    
    df[x_col] = pd.to_numeric(df[x_col], errors='coerce')
    df[y_col] = pd.to_numeric(df[y_col], errors='coerce')
    
    df = df.dropna(subset=[x_col, y_col])
    
    X = df[[x_col]]
    y = df[y_col]
    
    X = sm.add_constant(X)
    
    model = sm.OLS(y, X).fit()
    
    print(model.summary())
    
    return model

# %%
df = pd.read_csv('\\Users\\joshu\\Downloads\\UROP_Code\\Data\\graph_data.csv')

positive_cd = df[df['CD_Index'] > 0].groupby('earliest_pub_year')['CD_Index'].mean().reset_index()
negative_cd = df[df['CD_Index'] < 0].groupby('earliest_pub_year')['CD_Index'].mean().reset_index()

# %%
print("Regression on all data:")
run_ols_regression(df, 'earliest_pub_year', 'CD_Index')
# Out:
# Regression on all data:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               CD_Index   R-squared:                       0.026
# Model:                            OLS   Adj. R-squared:                  0.026
# Method:                 Least Squares   F-statistic:                     6857.
# Date:                Fri, 11 Apr 2025   Prob (F-statistic):               0.00
# Time:                        16:46:15   Log-Likelihood:                 75041.
# No. Observations:              254982   AIC:                        -1.501e+05
# Df Residuals:                  254980   BIC:                        -1.501e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                10.6663      0.128     83.058      0.000      10.415      10.918
# earliest_pub_year    -0.0053   6.37e-05    -82.808      0.000      -0.005      -0.005
# ==============================================================================
# Omnibus:                   232695.213   Durbin-Watson:                   1.926
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          6130500.733
# Skew:                           4.633   Prob(JB):                         0.00
# Kurtosis:                      25.163   Cond. No.                     7.25e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.25e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# C:\Users\joshu\AppData\Local\Temp\ipykernel_3404\459510201.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[x_col] = pd.to_numeric(df[x_col], errors='coerce')
# C:\Users\joshu\AppData\Local\Temp\ipykernel_3404\459510201.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[y_col] = pd.to_numeric(df[y_col], errors='coerce')

# %%
print("Regression on positive CD_Index:")
run_ols_regression(positive_cd, 'earliest_pub_year', 'CD_Index')
# Out:
# Regression on positive CD_Index:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               CD_Index   R-squared:                       0.871
# Model:                            OLS   Adj. R-squared:                  0.865
# Method:                 Least Squares   F-statistic:                     147.9
# Date:                Fri, 11 Apr 2025   Prob (F-statistic):           3.07e-11
# Time:                        16:46:26   Log-Likelihood:                 38.406
# No. Observations:                  24   AIC:                            -72.81
# Df Residuals:                      22   BIC:                            -70.46
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                37.2619      3.026     12.314      0.000      30.987      43.537
# earliest_pub_year    -0.0183      0.002    -12.162      0.000      -0.021      -0.015
# ==============================================================================
# Omnibus:                        0.163   Durbin-Watson:                   1.085
# Prob(Omnibus):                  0.922   Jarque-Bera (JB):                0.267
# Skew:                          -0.168   Prob(JB):                        0.875
# Kurtosis:                       2.608   Cond. No.                     5.85e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.85e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
print("Regression on negative CD_Index:")
run_ols_regression(negative_cd, 'earliest_pub_year', 'CD_Index')
# Out:
# Regression on negative CD_Index:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               CD_Index   R-squared:                       0.810
# Model:                            OLS   Adj. R-squared:                  0.801
# Method:                 Least Squares   F-statistic:                     93.81
# Date:                Fri, 11 Apr 2025   Prob (F-statistic):           2.15e-09
# Time:                        16:46:30   Log-Likelihood:                 95.664
# No. Observations:                  24   AIC:                            -187.3
# Df Residuals:                      22   BIC:                            -185.0
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                -2.7301      0.278     -9.805      0.000      -3.308      -2.153
# earliest_pub_year     0.0013      0.000      9.685      0.000       0.001       0.002
# ==============================================================================
# Omnibus:                        6.997   Durbin-Watson:                   0.629
# Prob(Omnibus):                  0.030   Jarque-Bera (JB):                4.948
# Skew:                          -1.041   Prob(JB):                       0.0842
# Kurtosis:                       3.782   Cond. No.                     5.85e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.85e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
